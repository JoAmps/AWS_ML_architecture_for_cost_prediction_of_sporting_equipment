# %%
import pandas as pd
import boto3
import numpy as np
from sklearn.model_selection import train_test_split
from preprocessing import datetime, read_dataset, find_season, create_weekday, scale_outliers, drop
import os
from sagemaker import get_execution_role
from sagemaker import image_uris
import io
import json

# %%
bucket='cost-prediction-sports-equipment'
data_key = 'spending.csv'
data_location = 's3://{}/{}'.format(bucket, data_key)
df=pd.read_csv(data_location)
df.head()
# Out:
#    Unnamed: 0        Date     mode_of_purchase sporting_equipment  store  \
# 0           0  2019-08-01                order            fitness   east
# 1           1  2019-08-01                order            jog/run  south
# 2           2  2019-08-01                order            pilates  south
# 3           3  2019-08-01                order            pilates   east
# 4           4  2019-08-01  physical_collection             diving   west
#
#    estimated_spending  number_of_items_bought
# 0             119.412                       5
# 1             212.506                       6
# 2             107.512                       4
# 3              65.651                       5
# 4              64.871                       2

# %%
df=datetime(df)    
season_list = []
for month in df['month']:
    season = find_season(month)
    season_list.append(season)
df['seasons'] = season_list
df=create_weekday(df)
df=scale_outliers(df)
df=drop(df)
df.head()
# Out:
# /home/ec2-user/SageMaker/preprocessing.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['estimated_spending'][df['estimated_spending']>3*UL]=3*UL
#       mode_of_purchase sporting_equipment  store  estimated_spending  \
# 0                order            fitness   east             119.412
# 1                order            jog/run  south             212.506
# 2                order            pilates  south             107.512
# 3                order            pilates   east              65.651
# 4  physical_collection             diving   west              64.871
#
#    number_of_items_bought seasons  weekday
# 0                       5  Summer  weekday
# 1                       6  Summer  weekday
# 2                       4  Summer  weekday
# 3                       5  Summer  weekday
# 4                       2  Summer  weekday

# %%
def split_data(df,test_size,valid_size):
    X = df.drop(columns=['estimated_spending'])
    y = df['estimated_spending']
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=test_size,random_state=0)
    X_train,X_valid,y_train,y_valid=train_test_split(X_train,y_train,test_size=valid_size,random_state=0)
    return X_train,X_valid,y_train,y_valid,X_test,y_test

X_train,X_valid,y_train,y_valid,X_test,y_test=split_data(df,0.15,0.2)

# %%
len(X_train),len(X_valid),len(X_test)
# Out:
# (34003, 8501, 7501)

# %%
def one_hot_encode(df):
    df=pd.get_dummies(df)
    return df

# %%
X_train=one_hot_encode(X_train)
X_valid=one_hot_encode(X_valid)
X_test=one_hot_encode(X_test)

# %%
data_dir = 'data'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
pd.DataFrame(X_test).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)
pd.concat([y_valid, X_valid], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([y_train, X_train], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %%
X_test.head()
# Out:
#        number_of_items_bought  mode_of_purchase_order  \
# 15638                       3                       0
# 27513                       8                       1
# 50034                       3                       1
# 10114                       5                       1
# 12564                      20                       1
#
#        mode_of_purchase_physical_collection  sporting_equipment_badminton  \
# 15638                                     1                             0
# 27513                                     0                             0
# 50034                                     0                             0
# 10114                                     0                             0
# 12564                                     0                             0
#
#        sporting_equipment_basketball  sporting_equipment_boxing  \
# 15638                              0                          0
# 27513                              0                          0
# 50034                              0                          0
# 10114                              0                          0
# 12564                              0                          0
#
#        sporting_equipment_climbing  sporting_equipment_crosstrain  \
# 15638                            0                              0
# 27513                            0                              0
# 50034                            0                              0
# 10114                            0                              0
# 12564                            0                              0
#
#        sporting_equipment_cycling  sporting_equipment_diving  ...  \
# 15638                           0                          0  ...
# 27513                           0                          0  ...
# 50034                           0                          0  ...
# 10114                           0                          0  ...
# 12564                           0                          0  ...
#
#        sporting_equipment_yoga  store_east  store_south  store_west  \
# 15638                        1           0            0           1
# 27513                        0           0            1           0
# 50034                        0           1            0           0
# 10114                        0           0            1           0
# 12564                        0           0            1           0
#
#        seasons_Autumn  seasons_Spring  seasons_Summer  seasons_Winter  \
# 15638               0               1               0               0
# 27513               1               0               0               0
# 50034               1               0               0               0
# 10114               0               0               0               1
# 12564               0               1               0               0
#
#        weekday_weekday  weekday_weekend
# 15638                1                0
# 27513                1                0
# 50034                1                0
# 10114                0                1
# 12564                0                1
#
# [5 rows x 40 columns]

# %%
import sagemaker

session = sagemaker.Session() 
bucket='cost-prediction-sports-equipment'

test_location = session.upload_data(os.path.join(data_dir, 'test.csv'),bucket=bucket)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), bucket=bucket)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'),bucket=bucket)

# %%
# Our current execution role is require when creating the model as the training
# and inference code will need to access the model artifacts.
role = get_execution_role()

# %%
# We need to retrieve the location of the container which is provided by Amazon for using XGBoost.
# As a matter of convenience, the training and inference code both use the same container.

container = image_uris.retrieve('xgboost', session.boto_region_name, 'latest')
prefix = 'cost-prediction-sports-equipment'

# %%
xgb = sagemaker.estimator.Estimator(container, 
                                    role,           
                                    instance_count=1,                  
                                    instance_type='ml.m4.xlarge',      
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                    sagemaker_session=session)

xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        silent=0,
                        eval_metric='rmse',
                        early_stopping_rounds=10,
                        num_round=500)

# %%
s3_input_train = sagemaker.TrainingInput(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.TrainingInput(s3_data=val_location, content_type='csv')

# %%
xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2022-05-21 09:04:16 Starting - Starting the training job...
# 2022-05-21 09:04:43 Starting - Preparing the instances for trainingProfilerReport-1653123856: InProgress
# ............
# 2022-05-21 09:06:40 Downloading - Downloading input data...
# 2022-05-21 09:07:12 Training - Downloading the training image......
# 2022-05-21 09:08:08 Training - Training image download completed. Training in progress.Arguments: train
# [2022-05-21:09:08:12:INFO] Running standalone xgboost training.
# [2022-05-21:09:08:12:INFO] File size need to be processed in the node: 3.71mb. Available memory size in the node: 8449.37mb
# [2022-05-21:09:08:12:INFO] Determined delimiter of CSV input is ','
# [09:08:12] S3DistributionType set as FullyReplicated
# [09:08:12] 34003x40 matrix with 1360120 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [
# [09:08:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [99]#011train-rmse:156.004#011validation-rmse:159.316
# [09:08:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [100]#011train-rmse:155.943#011validation-rmse:159.267
# [09:08:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [101]#011train-rmse:155.899#011validation-rmse:159.263
# [09:08:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [102]#011train-rmse:155.836#011validation-rmse:159.157
# [09:08:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=5
# [103]#011train-rmse:155.781#011validation-rmse:159.17
# [09:08:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=5
# [104]#011train-rmse:155.734#011validation-rmse:159.197
# [09:08:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [105]#011train-rmse:155.716#011validation-rmse:159.187
# [09:08:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [106]#011train-rmse:155.611#011validation-rmse:159.084
# [09:08:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [107]#011train-rmse:155.521#011validation-rmse:159.049
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [108]#011train-rmse:155.439#011validation-rmse:159.014
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [109]#011train-rmse:155.357#011validation-rmse:158.968
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=5
# [110]#011train-rmse:155.307#011validation-rmse:158.985
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [111]#011train-rmse:155.255#011validation-rmse:158.962
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [112]#011train-rmse:155.21#011validation-rmse:158.915
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [113]#011train-rmse:155.175#011validation-rmse:158.913
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [114]#011train-rmse:155.068#011validation-rmse:158.86
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [115]#011train-rmse:155.01#011validation-rmse:158.84
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [116]#011train-rmse:154.948#011validation-rmse:158.809
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [117]#011train-rmse:154.909#011validation-rmse:158.792
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [118]#011train-rmse:154.842#011validation-rmse:158.767
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [119]#011train-rmse:154.791#011validation-rmse:158.743
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [120]#011train-rmse:154.723#011validation-rmse:158.722
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [121]#011train-rmse:154.67#011validation-rmse:158.693
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [122]#011train-rmse:154.583#011validation-rmse:158.659
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [123]#011train-rmse:154.525#011validation-rmse:158.711
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [124]#011train-rmse:154.486#011validation-rmse:158.719
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [125]#011train-rmse:154.401#011validation-rmse:158.67
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [126]#011train-rmse:154.349#011validation-rmse:158.661
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=5
# [127]#011train-rmse:154.32#011validation-rmse:158.699
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [128]#011train-rmse:154.259#011validation-rmse:158.656
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [129]#011train-rmse:154.196#011validation-rmse:158.685
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [130]#011train-rmse:154.145#011validation-rmse:158.749
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=5
# [131]#011train-rmse:154.112#011validation-rmse:158.786
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [132]#011train-rmse:154.082#011validation-rmse:158.788
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [133]#011train-rmse:154.048#011validation-rmse:158.762
# [09:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [134]#011train-rmse:154.006#011validation-rmse:158.777
# [09:08:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [135]#011train-rmse:153.957#011validation-rmse:158.791
# [09:08:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [136]#011train-rmse:153.918#011validation-rmse:158.775
# [09:08:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [137]#011train-rmse:153.859#011validation-rmse:158.792
# [09:08:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [138]#011train-rmse:153.821#011validation-rmse:158.824
# Stopping. Best iteration:
# [128]#011train-rmse:154.259#011validation-rmse:158.656
#
# 2022-05-21 09:08:41 Uploading - Uploading generated training model
# 2022-05-21 09:08:41 Completed - Training job completed
# Training seconds: 127
# Billable seconds: 127

# %%
xgb_transformer = xgb.transformer(instance_count = 1, instance_type = 'ml.m4.xlarge')

# %%
xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')
# Out:
# ....................................
# Arguments: serve
# [2022-05-21 09:14:51 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2022-05-21 09:14:51 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2022-05-21 09:14:51 +0000] [1] [INFO] Using worker: gevent
# [2022-05-21 09:14:51 +0000] [21] [INFO] Booting worker with pid: 21
# [2022-05-21 09:14:51 +0000] [22] [INFO] Booting worker with pid: 22
# [2022-05-21 09:14:51 +0000] [23] [INFO] Booting worker with pid: 23
# [2022-05-21 09:14:51 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-05-21:09:14:51:INFO] Model loaded successfully for worker : 21
# [2022-05-21:09:14:51:INFO] Model loaded successfully for worker : 22
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-05-21:09:14:51:INFO] Model loaded successfully for worker : 23
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-05-21:09:14:51:INFO] Model loaded successfully for worker : 24
# [2022-05-21:09:14:55:INFO] Sniff delimiter as ','
# [2022-05-21:09:14:55:INFO] Determined delimiter of CSV input is ','
# 2022-05-21T09:14:55.385:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD

# %%
xgb_transformer.wait()
# Out:
# Arguments: serve
# Arguments: serve
# [2022-05-21 09:14:51 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2022-05-21 09:14:51 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2022-05-21 09:14:51 +0000] [1] [INFO] Using worker: gevent
# [2022-05-21 09:14:51 +0000] [21] [INFO] Booting worker with pid: 21
# [2022-05-21 09:14:51 +0000] [22] [INFO] Booting worker with pid: 22
# [2022-05-21 09:14:51 +0000] [23] [INFO] Booting worker with pid: 23
# [2022-05-21 09:14:51 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-05-21:09:14:51:INFO] Model loaded successfully for worker : 21
# [2022-05-21:09:14:51:INFO] Model loaded successfully for worker : 22
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-05-21:09:14:51:INFO] Model loaded successfully for worker : 23
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-05-21:09:14:51:INFO] Model loaded successfully for worker : 24
# [2022-05-21 09:14:51 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2022-05-21 09:14:51 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2022-05-21 09:14:51 +0000] [1] [INFO] Using worker: gevent
# [2022-05-21 09:14:51 +0000] [21] [INFO] Booting worker with pid: 21
# [2022-05-21 09:14:51 +0000] [22] [INFO] Booting worker with pid: 22
# [2022-05-21 09:14:51 +0000] [23] [INFO] Booting worker with pid: 23
# [2022-05-21 09:14:51 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-05-21:09:14:51:INFO] Model loaded successfully for worker : 21
# [2022-05-21:09:14:51:INFO] Model loaded successfully for worker : 22
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-05-21:09:14:51:INFO] Model loaded successfully for worker : 23
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-05-21:09:14:51:INFO] Model loaded successfully for worker : 24
# [2022-05-21:09:14:55:INFO] Sniff delimiter as ','
# [2022-05-21:09:14:55:INFO] Determined delimiter of CSV input is ','
# [2022-05-21:09:14:55:INFO] Sniff delimiter as ','
# [2022-05-21:09:14:55:INFO] Determined delimiter of CSV input is ','
# 2022-05-21T09:14:55.385:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD

# %%
xgb_predictor = xgb.deploy(initial_instance_count=1,instance_type='ml.m4.xlarge')
# Out:
# -----------!

# %%
endpoint_name = 'xgboost-2022-05-21-09-15-16-922'

# %%
def np2csv(arr):
    csv = io.BytesIO()
    np.savetxt(csv, arr, delimiter=",", fmt="%g")
    return csv.getvalue().decode().rstrip()

# %%
runtime = boto3.client("runtime.sagemaker")
payload = np2csv(pd.DataFrame(X_test[:1]))
response = runtime.invoke_endpoint(
    EndpointName=endpoint_name, ContentType="text/csv", Body=payload
)
result = json.loads(response["Body"].read().decode())
result
# Out:
# 71.19747924804688
