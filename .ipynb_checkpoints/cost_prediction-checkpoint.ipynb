# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import rcParams
from itertools import cycle, islice
#plt.style.use('ggplot')

# %%
df=pd.read_csv('costs.csv')
df.head()
# Out:
#    Unnamed: 0        Date     mode_of_purchase sporting_equipment  store  \
# 0           0  2019-08-01                order            fitness   east
# 1           1  2019-08-01                order            jog/run  south
# 2           2  2019-08-01                order            pilates  south
# 3           3  2019-08-01                order            pilates   east
# 4           4  2019-08-01  physical_collection             diving   west
#
#    estimated_spending  number_of_items_bought
# 0            167.1768                       7
# 1            297.5084                       8
# 2            150.5168                       5
# 3             91.9114                       7
# 4             90.8194                       2

# %%
df=df.drop(columns=['Unnamed: 0'])
df.head()
# Out:
#          Date     mode_of_purchase sporting_equipment  store  \
# 0  2019-08-01                order            fitness   east
# 1  2019-08-01                order            jog/run  south
# 2  2019-08-01                order            pilates  south
# 3  2019-08-01                order            pilates   east
# 4  2019-08-01  physical_collection             diving   west
#
#    estimated_spending  number_of_items_bought
# 0            167.1768                       7
# 1            297.5084                       8
# 2            150.5168                       5
# 3             91.9114                       7
# 4             90.8194                       2

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['month']=df['Date'].dt.month
df['day']=df['Date'].dt.day

# %%
df.head()
# Out:
#         Date     mode_of_purchase sporting_equipment  store  \
# 0 2019-08-01                order            fitness   east
# 1 2019-08-01                order            jog/run  south
# 2 2019-08-01                order            pilates  south
# 3 2019-08-01                order            pilates   east
# 4 2019-08-01  physical_collection             diving   west
#
#    estimated_spending  number_of_items_bought  month  day
# 0            167.1768                       7      8    1
# 1            297.5084                       8      8    1
# 2            150.5168                       5      8    1
# 3             91.9114                       7      8    1
# 4             90.8194                       2      8    1

# %%
df.isnull().sum()
# Out:
# Date                      0
# mode_of_purchase          0
# sporting_equipment        0
# store                     0
# estimated_spending        0
# number_of_items_bought    0
# month                     0
# day                       0
# dtype: int64

# %%
fig1, ax1 = plt.subplots(figsize=(9,9))
explode=(0,0.05, 0.05)
plt.pie(df['store'].value_counts(),labels=df['store'].unique(), explode=explode,shadow=True,
        startangle=90,autopct='%.2f')
ax1.axis('equal');
ax1.set_title('Percentage Of Customer Purchases in each Store',fontdict={'size':20});

# %%
plt.figure(figsize=(11,8))
ax = (df['mode_of_purchase'].value_counts()/len(df['mode_of_purchase'])*100).plot.bar(rot=90)
ax.bar_label(ax.containers[0], fmt='%.2f %%')
ax.margins(x=12)
plt.ylabel('Number of Customers')
plt.title('Distribution of the Mode Of Purchase of Equipment')
plt.show()

# %%
df.head()
# Out:
#         Date     mode_of_purchase sporting_equipment  store  \
# 0 2019-08-01                order            fitness   east
# 1 2019-08-01                order            jog/run  south
# 2 2019-08-01                order            pilates  south
# 3 2019-08-01                order            pilates   east
# 4 2019-08-01  physical_collection             diving   west
#
#    estimated_spending  number_of_items_bought  month  day
# 0            167.1768                       7      8    1
# 1            297.5084                       8      8    1
# 2            150.5168                       5      8    1
# 3             91.9114                       7      8    1
# 4             90.8194                       2      8    1

# %%
my_colors = list(islice(cycle(['b', 'r', 'g', 'y', 'k']), None, len(df)))
ax=df.groupby('sporting_equipment')['number_of_items_bought'].count().sort_values().plot(kind='barh',figsize=(10,13), color=my_colors)
ax.set_title('Number of Sports Equipments Bought',fontdict={'size':20});

# %%
plt.figure(figsize=(13,9))
sns.countplot(x='store', data=df)
plt.xlabel('Relationship status')
plt.ylabel('Number of customers')
plt.title('Relationship status among customers');

# %%
df['month']
# Out:
# 0         8
# 1         8
# 2         8
# 3         8
# 4         8
#          ..
# 46758    10
# 46759    10
# 46760    10
# 46761    10
# 46762    10
# Name: month, Length: 46763, dtype: int64

# %%
df['seasons']=(pd.cut(df['month'], [3,5,8,11,14], labels=['spring','summer','autumn','Winter'], right=False,include_lowest=True))
df['seasons'].value_counts()
# Out:
# autumn    15658
# summer    10361
# Winter     7051
# spring     6899
# Name: seasons, dtype: int64

# %%
df.groupby('seasons')['estimated_spending'].mean().sort_values(ascending=False).plot(kind='bar',figsize=(11,10))
# Out:
# <AxesSubplot:xlabel='seasons'>

# %%
df.head(3)
# Out:
#         Date mode_of_purchase sporting_equipment  store  estimated_spending  \
# 0 2019-08-01            order            fitness   east            167.1768
# 1 2019-08-01            order            jog/run  south            297.5084
# 2 2019-08-01            order            pilates  south            150.5168
#
#    number_of_items_bought  month  day seasons
# 0                       7      8    1  autumn
# 1                       8      8    1  autumn
# 2                       5      8    1  autumn

# %%
df.groupby('store')['estimated_spending'].mean().sort_values(ascending=False).plot(kind='bar',figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='store'>

# %%
df['seasons']=(pd.cut(df['month'], [3,5,8,11,14], labels=['spring','summer','autumn','Winter'], right=False,include_lowest=True))
df['seasons'].value_counts()
# Out:
# autumn    15658
# summer    10361
# Winter     7051
# spring     6899
# Name: seasons, dtype: int64

# %%
df['weekday']=np.where((df['Date'].dt.dayofweek) < 5,'weekday','weekend')

# %%
df['weekday'].value_counts()
# Out:
# weekday    33522
# weekend    13241
# Name: weekday, dtype: int64

# %%
df
# Out:
#             Date     mode_of_purchase sporting_equipment  store  \
# 0     2019-08-01                order            fitness   east
# 1     2019-08-01                order            jog/run  south
# 2     2019-08-01                order            pilates  south
# 3     2019-08-01                order            pilates   east
# 4     2019-08-01  physical_collection             diving   west
# ...          ...                  ...                ...    ...
# 46758 2021-10-31                order           swimming  south
# 46759 2021-10-31                order         basketball  south
# 46760 2021-10-31                order          triathlon   east
# 46761 2021-10-31                order             tennis  south
# 46762 2021-10-31                order            sailing   east
#
#        estimated_spending  number_of_items_bought  month  day seasons  weekday
# 0              167.176800                       7      8    1  autumn  weekday
# 1              297.508400                       8      8    1  autumn  weekday
# 2              150.516800                       5      8    1  autumn  weekday
# 3               91.911400                       7      8    1  autumn  weekday
# 4               90.819400                       2      8    1  autumn  weekday
# ...                   ...                     ...    ...  ...     ...      ...
# 46758           87.588667                       4     10   31  autumn  weekend
# 46759           19.809333                       1     10   31  autumn  weekend
# 46760           46.942667                       1     10   31  autumn  weekend
# 46761          154.963333                       5     10   31  autumn  weekend
# 46762           27.650000                       2     10   31  autumn  weekend
#
# [46763 rows x 10 columns]

# %%
df.groupby('weekday')['estimated_spending'].max().sort_values(ascending=False).plot(kind='bar',figsize=(10,8))
# Out:
# <AxesSubplot:xlabel='weekday'>

# %%
df.groupby('weekday')['estimated_spending','number_of_items_bought'].mean().sort_values(by='estimated_spending',ascending=False)
# Out:
#          estimated_spending  number_of_items_bought
# weekday
# weekday          636.515728                7.900304
# weekend          518.045857                6.849634

# %%
df
# Out:
#             Date     mode_of_purchase sporting_equipment  store  \
# 0     2019-08-01                order            fitness   east
# 1     2019-08-01                order            jog/run  south
# 2     2019-08-01                order            pilates  south
# 3     2019-08-01                order            pilates   east
# 4     2019-08-01  physical_collection             diving   west
# ...          ...                  ...                ...    ...
# 46758 2021-10-31                order           swimming  south
# 46759 2021-10-31                order         basketball  south
# 46760 2021-10-31                order          triathlon   east
# 46761 2021-10-31                order             tennis  south
# 46762 2021-10-31                order            sailing   east
#
#        estimated_spending  number_of_items_bought  month  day seasons  weekday
# 0              167.176800                       7      8    1  autumn  weekday
# 1              297.508400                       8      8    1  autumn  weekday
# 2              150.516800                       5      8    1  autumn  weekday
# 3               91.911400                       7      8    1  autumn  weekday
# 4               90.819400                       2      8    1  autumn  weekday
# ...                   ...                     ...    ...  ...     ...      ...
# 46758           87.588667                       4     10   31  autumn  weekend
# 46759           19.809333                       1     10   31  autumn  weekend
# 46760           46.942667                       1     10   31  autumn  weekend
# 46761          154.963333                       5     10   31  autumn  weekend
# 46762           27.650000                       2     10   31  autumn  weekend
#
# [46763 rows x 10 columns]

# %%
df.groupby(['sporting_equipment'])['estimated_spending','number_of_items_bought'].mean().sort_values(by='estimated_spending',ascending=False)
# Out:
#                     estimated_spending  number_of_items_bought
# sporting_equipment
# hiking/trekking            3610.841787               31.276338
# ski                        1384.178828               12.161817
# jog/run                    1322.431171               17.490893
# swimming                    916.066222               13.299339
# crosstrain                  572.116406                5.909251
# fitness                     553.866330                8.034070
# surfing                     513.277982                6.555160
# pilates                     501.761503                8.664742
# tennis                      480.692037                9.321154
# football                    443.889394                5.908534
# cycling                     409.018160                5.746392
# diving                      386.958421                4.817571
# basketball                  384.938072                6.060559
# yoga                        377.533365                4.822709
# skate/roller                353.162038                3.244161
# trail                       295.072338                3.204307
# triathlon                   265.417716                6.338545
# badminton                   218.967309                3.746828
# kayak/sup                   185.985688                2.797030
# sailing                     154.556953                2.776438
# climbing                    129.076029                2.788798
# others                      103.130918                2.881432
# boxing                      101.179663                2.655518
# golf                         85.715425                2.784447
# unknown                      51.900159                2.775439
# table_tennis                 51.463600                2.826434
# rugby                        38.360185                2.676667
# squash                       32.345838                2.513889
# volleyball                   28.664099                2.883055

# %%
df.head()
# Out:
#         Date     mode_of_purchase sporting_equipment  store  \
# 0 2019-08-01                order            fitness   east
# 1 2019-08-01                order            jog/run  south
# 2 2019-08-01                order            pilates  south
# 3 2019-08-01                order            pilates   east
# 4 2019-08-01  physical_collection             diving   west
#
#    estimated_spending  number_of_items_bought  month  day seasons  weekday
# 0            167.1768                       7      8    1  autumn  weekday
# 1            297.5084                       8      8    1  autumn  weekday
# 2            150.5168                       5      8    1  autumn  weekday
# 3             91.9114                       7      8    1  autumn  weekday
# 4             90.8194                       2      8    1  autumn  weekday

# %%
df.head()
# Out:
#         Date     mode_of_purchase sporting_equipment  store  \
# 0 2019-08-01                order            fitness   east
# 1 2019-08-01                order            jog/run  south
# 2 2019-08-01                order            pilates  south
# 3 2019-08-01                order            pilates   east
# 4 2019-08-01  physical_collection             diving   west
#
#    estimated_spending  number_of_items_bought  month  day seasons  weekday
# 0            167.1768                       7      8    1  autumn  weekday
# 1            297.5084                       8      8    1  autumn  weekday
# 2            150.5168                       5      8    1  autumn  weekday
# 3             91.9114                       7      8    1  autumn  weekday
# 4             90.8194                       2      8    1  autumn  weekday

# %%
df['Corona_effect']=np.where((df['Date']) > '2020-03-10','corona_effect','before_corona')

# %%
df
# Out:
#             Date     mode_of_purchase sporting_equipment  store  \
# 0     2019-08-01                order            fitness   east
# 1     2019-08-01                order            jog/run  south
# 2     2019-08-01                order            pilates  south
# 3     2019-08-01                order            pilates   east
# 4     2019-08-01  physical_collection             diving   west
# ...          ...                  ...                ...    ...
# 46758 2021-10-31                order           swimming  south
# 46759 2021-10-31                order         basketball  south
# 46760 2021-10-31                order          triathlon   east
# 46761 2021-10-31                order             tennis  south
# 46762 2021-10-31                order            sailing   east
#
#        estimated_spending  number_of_items_bought  month  day seasons  \
# 0              167.176800                       7      8    1  autumn
# 1              297.508400                       8      8    1  autumn
# 2              150.516800                       5      8    1  autumn
# 3               91.911400                       7      8    1  autumn
# 4               90.819400                       2      8    1  autumn
# ...                   ...                     ...    ...  ...     ...
# 46758           87.588667                       4     10   31  autumn
# 46759           19.809333                       1     10   31  autumn
# 46760           46.942667                       1     10   31  autumn
# 46761          154.963333                       5     10   31  autumn
# 46762           27.650000                       2     10   31  autumn
#
#        weekday  Corona_effect
# 0      weekday  before_corona
# 1      weekday  before_corona
# 2      weekday  before_corona
# 3      weekday  before_corona
# 4      weekday  before_corona
# ...        ...            ...
# 46758  weekend  corona_effect
# 46759  weekend  corona_effect
# 46760  weekend  corona_effect
# 46761  weekend  corona_effect
# 46762  weekend  corona_effect
#
# [46763 rows x 11 columns]

# %%
df.groupby('Corona_effect')['estimated_spending'].mean().plot(kind='bar',figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Corona_effect'>

# %%
df.groupby('Corona_effect')['number_of_items_bought'].mean().plot(kind='bar',figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Corona_effect'>

# %%
leadtimereg=pd.crosstab(df['Corona_effect'], df['mode_of_purchase'],normalize='index').mul(100).sort_values(by='order',ascending=False)
ax = leadtimereg['order'].plot.bar(rot=90)
ax.bar_label(ax.containers[0], fmt='%.2f %%')
ax.margins(x=15)
plt.show()

# %%
leadtimereg
# Out:
# mode_of_purchase      order  physical_collection
# Corona_effect
# before_corona     79.633153            20.366847
# corona_effect     78.777064            21.222936

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='mode_of_purchase', data=df,hue='Corona_effect')
plt.xlabel('Relationship status')
plt.ylabel('Number of customers')
plt.title('Relationship status among customers');

# %%
sns.set(style="darkgrid")
sns.set_palette("hls", 3)
fig, ax = plt.subplots(figsize=(13,10))
ax = sns.countplot(x="Corona_effect", hue="mode_of_purchase", data=df)

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format(height/df.shape[0]),
            ha="center")

# %%
df.groupby('seasons')['number_of_items_bought'].mean().sort_values(ascending=False).plot(kind='bar',figsize=(11,10))
# Out:
# <AxesSubplot:xlabel='seasons'>
